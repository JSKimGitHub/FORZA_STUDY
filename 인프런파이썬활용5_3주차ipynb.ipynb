# %% [markdown]
# <a href="https://colab.research.google.com/github/JSKimGitHub/FORZA_STUDY/blob/main/%EC%9D%B8%ED%94%84%EB%9F%B0%ED%8C%8C%EC%9D%B4%EC%8D%AC%ED%99%9C%EC%9A%A95_3%EC%A3%BC%EC%B0%A8ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 데이터 수정, 함수 적용, 그룹화 , 퀴즈, 그래프 기본, 축

# %% [markdown]
# #12. 데이터 수정

# %%
import pandas as pd
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', 'NaN', 'NaN', 'C', 'PYTHON', 'C#']
}
df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80         NaN
# 5번  강백호  북산고  188   15   20   10  35  10         NaN
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ##Column 수정

# %%
df['학교'].replace({'북산고':'상북고','능남고':'무슨고'})
# Out:
# 1번    상북고
# 2번    상북고
# 3번    상북고
# 4번    상북고
# 5번    상북고
# 6번    무슨고
# 7번    무슨고
# 8번    무슨고
# Name: 학교, dtype: object

# %%
df['학교'].replace({'북산고':'상북고','능남고':'무슨고'},inplace=True)

# %%
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  상북고  197   90   85  100  95  85      Python
# 2번  정대만  상북고  184   40   35   50  55  25        Java
# 3번  송태섭  상북고  168   80   75   70  80  75  Javascript
# 4번  서태웅  상북고  187   40   60   70  75  80         NaN
# 5번  강백호  상북고  188   15   20   10  35  10         NaN
# 6번  변덕규  무슨고  202   80  100   95  85  80           C
# 7번  황태산  무슨고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  무슨고  190  100   85   90  95  95          C#

# %%
df['SW특기'].str.lower()
# Out:
# 1번        python
# 2번          java
# 3번    javascript
# 4번           nan
# 5번           nan
# 6번             c
# 7번        python
# 8번            c#
# Name: SW특기, dtype: object

# %%
df['SW특기']= df['SW특기'].str.lower()
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  상북고  197   90   85  100  95  85      python
# 2번  정대만  상북고  184   40   35   50  55  25        java
# 3번  송태섭  상북고  168   80   75   70  80  75  javascript
# 4번  서태웅  상북고  187   40   60   70  75  80         nan
# 5번  강백호  상북고  188   15   20   10  35  10         nan
# 6번  변덕규  무슨고  202   80  100   95  85  80           c
# 7번  황태산  무슨고  188   55   65   45  40  35      python
# 8번  윤대협  무슨고  190  100   85   90  95  95          c#

# %%
df['SW특기']=df['SW특기'].str.lower()
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  상북고  197   90   85  100  95  85      python
# 2번  정대만  상북고  184   40   35   50  55  25        java
# 3번  송태섭  상북고  168   80   75   70  80  75  javascript
# 4번  서태웅  상북고  187   40   60   70  75  80         nan
# 5번  강백호  상북고  188   15   20   10  35  10         nan
# 6번  변덕규  무슨고  202   80  100   95  85  80           c
# 7번  황태산  무슨고  188   55   65   45  40  35      python
# 8번  윤대협  무슨고  190  100   85   90  95  95          c#

# %%
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  상북고  197   90   85  100  95  85      python
# 2번  정대만  상북고  184   40   35   50  55  25        java
# 3번  송태섭  상북고  168   80   75   70  80  75  javascript
# 4번  서태웅  상북고  187   40   60   70  75  80         nan
# 5번  강백호  상북고  188   15   20   10  35  10         nan
# 6번  변덕규  무슨고  202   80  100   95  85  80           c
# 7번  황태산  무슨고  188   55   65   45  40  35      python
# 8번  윤대협  무슨고  190  100   85   90  95  95          c#

# %%
df['학교']+='학교'
df
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  상북고학교  197   90   85  100  95  85      python
# 2번  정대만  상북고학교  184   40   35   50  55  25        java
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript
# 4번  서태웅  상북고학교  187   40   60   70  75  80         nan
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#

# %% [markdown]
# ##Column 추가

# %%
df['총합']=df['국어']+df['영어']+df['수학']+df['과학']+df['사회']

# %%
df
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 1번  채치수  상북고학교  197   90   85  100  95  85      python  455
# 2번  정대만  상북고학교  184   40   35   50  55  25        java  205
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript  380
# 4번  서태웅  상북고학교  187   40   60   70  75  80         nan  325
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan   90
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c  440
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python  240
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#  465

# %%
df['결과']='Fail'
df
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수  상북고학교  197   90   85  100  95  85      python  455  Fail
# 2번  정대만  상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 4번  서태웅  상북고학교  187   40   60   70  75  80         nan  325  Fail
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan   90  Fail
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c  440  Fail
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#  465  Fail

# %%
df.loc[df['총합']>400,'결과']='Pass' #총합이 400보다 큰 데이터에 대해서 결과를 Pass로 변경

# %%
df
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수  상북고학교  197   90   85  100  95  85      python  455  Pass
# 2번  정대만  상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 4번  서태웅  상북고학교  187   40   60   70  75  80         nan  325  Fail
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan   90  Fail
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c  440  Pass
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#  465  Pass

# %% [markdown]
# ##Column 삭제

# %%
df.drop(columns=['총합']) #총합 Column을 삭제
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기    결과
# 1번  채치수  상북고학교  197   90   85  100  95  85      python  Pass
# 2번  정대만  상북고학교  184   40   35   50  55  25        java  Fail
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript  Fail
# 4번  서태웅  상북고학교  187   40   60   70  75  80         nan  Fail
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan  Fail
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c  Pass
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python  Fail
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#  Pass

# %%
df.drop(columns=['국어','영어','수학'])
# Out:
#      이름     학교    키  과학  사회        SW특기   총합    결과
# 1번  채치수  상북고학교  197  95  85      python  455  Pass
# 2번  정대만  상북고학교  184  55  25        java  205  Fail
# 3번  송태섭  상북고학교  168  80  75  javascript  380  Fail
# 4번  서태웅  상북고학교  187  75  80         nan  325  Fail
# 5번  강백호  상북고학교  188  35  10         nan   90  Fail
# 6번  변덕규  무슨고학교  202  85  80           c  440  Pass
# 7번  황태산  무슨고학교  188  40  35      python  240  Fail
# 8번  윤대협  무슨고학교  190  95  95          c#  465  Pass

# %%
df
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수  상북고학교  197   90   85  100  95  85      python  455  Pass
# 2번  정대만  상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 4번  서태웅  상북고학교  187   40   60   70  75  80         nan  325  Fail
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan   90  Fail
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c  440  Pass
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#  465  Pass

# %% [markdown]
# ##Row 삭제

# %%
df.drop(index='4번')
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수  상북고학교  197   90   85  100  95  85      python  455  Pass
# 2번  정대만  상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭  상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 5번  강백호  상북고학교  188   15   20   10  35  10         nan   90  Fail
# 6번  변덕규  무슨고학교  202   80  100   95  85  80           c  440  Pass
# 7번  황태산  무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협  무슨고학교  190  100   85   90  95  95          c#  465  Pass

# %%
filt=df['수학']<80
df[filt]
# Out:
#      이름     학교    키  국어  영어  수학  과학  사회        SW특기   총합    결과
# 2번  정대만  상북고학교  184  40  35  50  55  25        java  205  Fail
# 3번  송태섭  상북고학교  168  80  75  70  80  75  javascript  380  Fail
# 4번  서태웅  상북고학교  187  40  60  70  75  80         nan  325  Fail
# 5번  강백호  상북고학교  188  15  20  10  35  10         nan   90  Fail
# 7번  황태산  무슨고학교  188  55  65  45  40  35      python  240  Fail

# %%
df[filt].index
# Out:
# Index(['2번', '3번', '4번', '5번', '7번'], dtype='object')

# %%
df.drop(index=df[filt].index)
# Out:
#      이름     학교    키   국어   영어   수학  과학  사회    SW특기   총합    결과
# 1번  채치수  상북고학교  197   90   85  100  95  85  python  455  Pass
# 6번  변덕규  무슨고학교  202   80  100   95  85  80       c  440  Pass
# 8번  윤대협  무슨고학교  190  100   85   90  95  95      c#  465  Pass

# %% [markdown]
# ##Row 추가

# %%
df.loc['9번']=['이정환','해남고등학교',184,90,90,90,90,90,'Kotlin',450,'Pass']

# %%
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수   상북고학교  197   90   85  100  95  85      python  455  Pass
# 2번  정대만   상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭   상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 4번  서태웅   상북고학교  187   40   60   70  75  80         nan  325  Fail
# 5번  강백호   상북고학교  188   15   20   10  35  10         nan   90  Fail
# 6번  변덕규   무슨고학교  202   80  100   95  85  80           c  440  Pass
# 7번  황태산   무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협   무슨고학교  190  100   85   90  95  95          c#  465  Pass
# 9번  이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %% [markdown]
# ##Cell 수정

# %%
df.loc['4번','SW특기']='Python'
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수   상북고학교  197   90   85  100  95  85      python  455  Pass
# 2번  정대만   상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭   상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 4번  서태웅   상북고학교  187   40   60   70  75  80      Python  325  Fail
# 5번  강백호   상북고학교  188   15   20   10  35  10         nan   90  Fail
# 6번  변덕규   무슨고학교  202   80  100   95  85  80           c  440  Pass
# 7번  황태산   무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협   무슨고학교  190  100   85   90  95  95          c#  465  Pass
# 9번  이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %%
df.loc['5번',['학교','SW특기']]=['능남고등학교','C']

# %%
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합    결과
# 1번  채치수   상북고학교  197   90   85  100  95  85      python  455  Pass
# 2번  정대만   상북고학교  184   40   35   50  55  25        java  205  Fail
# 3번  송태섭   상북고학교  168   80   75   70  80  75  javascript  380  Fail
# 4번  서태웅   상북고학교  187   40   60   70  75  80      Python  325  Fail
# 5번  강백호  능남고등학교  188   15   20   10  35  10           C   90  Fail
# 6번  변덕규   무슨고학교  202   80  100   95  85  80           c  440  Pass
# 7번  황태산   무슨고학교  188   55   65   45  40  35      python  240  Fail
# 8번  윤대협   무슨고학교  190  100   85   90  95  95          c#  465  Pass
# 9번  이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450  Pass

# %% [markdown]
# ##Column 순서 변경

# %%
cols=list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기', '총합', '결과']

# %%
df=df[[cols[-1]]+cols[0:-1]]
df
# Out:
#       결과   이름      학교    키   국어   영어   수학  과학  사회        SW특기   총합
# 1번  Pass  채치수   상북고학교  197   90   85  100  95  85      python  455
# 2번  Fail  정대만   상북고학교  184   40   35   50  55  25        java  205
# 3번  Fail  송태섭   상북고학교  168   80   75   70  80  75  javascript  380
# 4번  Fail  서태웅   상북고학교  187   40   60   70  75  80      Python  325
# 5번  Fail  강백호  능남고등학교  188   15   20   10  35  10           C   90
# 6번  Pass  변덕규   무슨고학교  202   80  100   95  85  80           c  440
# 7번  Fail  황태산   무슨고학교  188   55   65   45  40  35      python  240
# 8번  Pass  윤대협   무슨고학교  190  100   85   90  95  95          c#  465
# 9번  Pass  이정환  해남고등학교  184   90   90   90  90  90      Kotlin  450

# %% [markdown]
# ##Column 이름 변경

# %%
df=df[['결과','이름','학교']]
df
# Out:
#       결과   이름      학교
# 1번  Pass  채치수   상북고학교
# 2번  Fail  정대만   상북고학교
# 3번  Fail  송태섭   상북고학교
# 4번  Fail  서태웅   상북고학교
# 5번  Fail  강백호  능남고등학교
# 6번  Pass  변덕규   무슨고학교
# 7번  Fail  황태산   무슨고학교
# 8번  Pass  윤대협   무슨고학교
# 9번  Pass  이정환  해남고등학교

# %%
 df.columns
# Out:
# Index(['결과', '이름', '학교'], dtype='object')

# %%
df.columns=['Result','Name','School']
df
# Out:
#    Result Name  School
# 1번   Pass  채치수   상북고학교
# 2번   Fail  정대만   상북고학교
# 3번   Fail  송태섭   상북고학교
# 4번   Fail  서태웅   상북고학교
# 5번   Fail  강백호  능남고등학교
# 6번   Pass  변덕규   무슨고학교
# 7번   Fail  황태산   무슨고학교
# 8번   Pass  윤대협   무슨고학교
# 9번   Pass  이정환  해남고등학교

# %% [markdown]
# #13 함수 적용

# %%
import pandas as pd
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript','' , '', 'C', 'PYTHON', 'C#']
}
df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['학교']=df['학교']+'등학교'

# %%
df
# Out:
#      이름      학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고등학교  197   90   85  100  95  85      Python
# 2번  정대만  북산고등학교  184   40   35   50  55  25        Java
# 3번  송태섭  북산고등학교  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고등학교  187   40   60   70  75  80         NaN
# 5번  강백호  북산고등학교  188   15   20   10  35  10         NaN
# 6번  변덕규  능남고등학교  202   80  100   95  85  80           C
# 7번  황태산  능남고등학교  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고등학교  190  100   85   90  95  95          C#

# %% [markdown]
# ##데이터에 함수 적용(apply)

# %%
#키 뒤에 cm을 붙이는 역할
def add_cm(height):
  return str(height)+'cm'
df['키']=df['키'].apply(add_cm)
df
# Out:
#      이름   학교      키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197cm   90   85  100  95  85      Python
# 2번  정대만  북산고  184cm   40   35   50  55  25        Java
# 3번  송태섭  북산고  168cm   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187cm   40   60   70  75  80
# 5번  강백호  북산고  188cm   15   20   10  35  10
# 6번  변덕규  능남고  202cm   80  100   95  85  80           C
# 7번  황태산  능남고  188cm   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190cm  100   85   90  95  95          C#

# %%
def capitalize(lang):
  if pd.notnull(lang):
    return lang.capitalize()
  return lang
df['SW특기']=df['SW특기'].apply(capitalize)
df
# Out:
#      이름   학교      키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197cm   90   85  100  95  85      Python
# 2번  정대만  북산고  184cm   40   35   50  55  25        Java
# 3번  송태섭  북산고  168cm   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187cm   40   60   70  75  80
# 5번  강백호  북산고  188cm   15   20   10  35  10
# 6번  변덕규  능남고  202cm   80  100   95  85  80           C
# 7번  황태산  능남고  188cm   55   65   45  40  35      Python
# 8번  윤대협  능남고  190cm  100   85   90  95  95          C#

# %% [markdown]
# #14 그룹화

# %%
import pandas as pd
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript','' , '', 'C', 'PYTHON', 'C#']
}

df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.groupby('학교')

# %%
df.groupby('학교').get_group('북산고')
# Out:
#      이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197  90  85  100  95  85      Python
# 2번  정대만  북산고  184  40  35   50  55  25        Java
# 3번  송태섭  북산고  168  80  75   70  80  75  Javascript
# 4번  서태웅  북산고  187  40  60   70  75  80
# 5번  강백호  북산고  188  15  20   10  35  10

# %%
df.groupby('학교').get_group('능남고')
# Out:
#      이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 6번  변덕규  능남고  202   80  100  95  85  80       C
# 7번  황태산  능남고  188   55   65  45  40  35  PYTHON
# 8번  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df.groupby('학교').mean(numeric_only=True)
# Out:
#               키         국어         영어         수학         과학    사회
# 학교
# 능남고  193.333333  78.333333  83.333333  76.666667  73.333333  70.0
# 북산고  184.800000  53.000000  55.000000  60.000000  68.000000  55.0

# %%
df.groupby('학교').size()
# Out:
# 학교
# 능남고    3
# 북산고    5
# dtype: int64

# %%
df.groupby('학교').size()['능남고']
# Out:
# 3

# %%
df.groupby('학교')['키'].mean()
# Out:
# 학교
# 능남고    193.333333
# 북산고    184.800000
# Name: 키, dtype: float64

# %%
df.groupby('학교')[['국어','영어','수학']].mean()
# Out:
#             국어         영어         수학
# 학교
# 능남고  78.333333  83.333333  76.666667
# 북산고  53.000000  55.000000  60.000000

# %%
df['학년']=[3,3,2,1,1,3,2,2]
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기  학년
# 1번  채치수  북산고  197   90   85  100  95  85      Python   3
# 2번  정대만  북산고  184   40   35   50  55  25        Java   3
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript   2
# 4번  서태웅  북산고  187   40   60   70  75  80               1
# 5번  강백호  북산고  188   15   20   10  35  10               1
# 6번  변덕규  능남고  202   80  100   95  85  80           C   3
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON   2
# 8번  윤대협  능남고  190  100   85   90  95  95          C#   2

# %%
df.groupby(['학교','학년']).mean(numeric_only=True)
# Out:
#             키    국어     영어    수학    과학    사회
# 학교  학년
# 능남고 2   189.0  77.5   75.0  67.5  67.5  65.0
#     3   202.0  80.0  100.0  95.0  85.0  80.0
# 북산고 1   187.5  27.5   40.0  40.0  55.0  45.0
#     2   168.0  80.0   75.0  70.0  80.0  75.0
#     3   190.5  65.0   60.0  75.0  75.0  55.0

# %%
df.groupby('학년').mean(numeric_only=True)
# Out:
#              키         국어         영어         수학         과학         사회
# 학년
# 1   187.500000  27.500000  40.000000  40.000000  55.000000  45.000000
# 2   182.000000  78.333333  75.000000  68.333333  71.666667  68.333333
# 3   194.333333  70.000000  73.333333  81.666667  78.333333  63.333333

# %%
df.groupby('학년').mean(numeric_only=True).sort_values('키')
# Out:
#              키         국어         영어         수학         과학         사회
# 학년
# 2   182.000000  78.333333  75.000000  68.333333  71.666667  68.333333
# 1   187.500000  27.500000  40.000000  40.000000  55.000000  45.000000
# 3   194.333333  70.000000  73.333333  81.666667  78.333333  63.333333

# %%
df.groupby('학년').mean(numeric_only=True).sort_values('키',ascending=False)
# Out:
#              키         국어         영어         수학         과학         사회
# 학년
# 3   194.333333  70.000000  73.333333  81.666667  78.333333  63.333333
# 1   187.500000  27.500000  40.000000  40.000000  55.000000  45.000000
# 2   182.000000  78.333333  75.000000  68.333333  71.666667  68.333333

# %%
df.groupby(['학교','학년']).sum()
# Out:
#             이름    키   국어   영어   수학   과학   사회        SW특기
# 학교  학년
# 능남고 2   황태산윤대협  378  155  150  135  135  130    PYTHONC#
#     3      변덕규  202   80  100   95   85   80           C
# 북산고 1   서태웅강백호  375   55   80   80  110   90
#     2      송태섭  168   80   75   70   80   75  Javascript
#     3   채치수정대만  381  130  120  150  150  110  PythonJava

# %%
df.groupby('학교')[['이름','SW특기']].count()
# Out:
#      이름  SW특기
# 학교
# 능남고   3     3
# 북산고   5     5

# %%
school=df.groupby('학교')
school['학년'].value_counts()
# Out:
# 학교   학년
# 능남고  2     2
#      3     1
# 북산고  1     2
#      3     2
#      2     1
# Name: count, dtype: int64

# %%
school['학년'].value_counts().loc['북산고']
# Out:
# 학년
# 1    2
# 3    2
# 2    1
# Name: count, dtype: int64

# %%
school['학년'].value_counts().loc['능남고']
# Out:
# 학년
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
school['학년'].value_counts(normalize=True).loc['북산고']
# Out:
# 학년
# 1    0.4
# 3    0.4
# 2    0.2
# Name: proportion, dtype: float64

# %% [markdown]
# #15 퀴즈

# %%
import pandas as pd
data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %% [markdown]
# #16 그래프 기본

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[2,4,8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot([-1,0,1],[-5,-1,-2])

# %% [markdown]
# #17 축

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Liberation Mono'
matplotlib.rcParams['font.size']=15
matplotlib.rcParams['axes.unicode_minus']=False

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmmi10',
#  'STIXGeneral',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'cmex10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'cmtt10',
#  'cmsy10',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmr10',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Liberation Mono',
#  'Liberation Sans Narrow',
#  'Liberation Mono',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Liberation Serif',
#  'Liberation Sans Narrow',
#  'Liberation Sans',
#  'Liberation Serif',
#  'Liberation Sans Narrow',
#  'Humor Sans',
#  'Liberation Mono',
#  'Liberation Sans',
#  'Liberation Mono']

# %%
x=[1,2,3]
y=[2,4,8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('x',color='red',loc='right')
plt.ylabel('y',color='#00aa00',loc='top')
# Out:
# Text(0, 1, 'y')

# %%
plt.plot(x,y)
plt.xticks([1,2,3])
plt.yticks([3,6,9,12])
plt.show()
