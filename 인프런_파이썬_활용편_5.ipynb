# %% [markdown]
# <a href="https://colab.research.google.com/github/JSKimGitHub/FORZA_STUDY/blob/main/%EC%9D%B8%ED%94%84%EB%9F%B0_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%ED%99%9C%EC%9A%A9%ED%8E%B8_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FORZA 스터디 데이터팀 1주

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %% [markdown]
# #1주차

# %% [markdown]
# ##Series

# %% [markdown]
# ###Series 객체 생성

# %%
temp=pd.Series([0,10,20,30,40,50,60])
temp
# Out:
# 0     0
# 1    10
# 2    20
# 3    30
# 4    40
# 5    50
# 6    60
# dtype: int64

# %%
temp[0] #1월 온도
# Out:
# 0

# %%
temp[2] #3월 온도
# Out:
# 20

# %%
temp=pd.Series([0,10,20,30,40], index=['Jan','Feb','Mar','Apr','May'])
temp
# Out:
# Jan     0
# Feb    10
# Mar    20
# Apr    30
# May    40
# dtype: int64

# %%
temp['Apr'] #indes Apr에 해당하는 데이터 출력
# Out:
# 30

# %%
temp['Jun']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Jun'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ##Data Frame

# %% [markdown]
#  Data Frame = 2차원 데이터(Series들의 모임)

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
data
# Out:
# {'이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
#  '학교': ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
#  '키': [197, 184, 168, 187, 188, 202, 188, 190],
#  '국어': [90, 40, 80, 40, 15, 80, 55, 100],
#  '영어': [85, 35, 75, 60, 20, 100, 65, 85],
#  '수학': [100, 50, 70, 70, 10, 95, 45, 90],
#  '과학': [95, 55, 80, 75, 35, 85, 40, 95],
#  '사회': [85, 25, 75, 80, 10, 80, 35, 95],
#  'SW특기': ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']}

# %%
data['이름']
# Out:
# ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

# %%
data['키']
# Out:
# [197, 184, 168, 187, 188, 202, 188, 190]

# %% [markdown]
# ###DataFrame 객체 생성

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ###데이터 접근

# %%
df['이름']
# Out:
# 0    채치수
# 1    정대만
# 2    송태섭
# 3    서태웅
# 4    강백호
# 5    변덕규
# 6    황태산
# 7    윤대협
# Name: 이름, dtype: object

# %%
df[['이름','키']]
# Out:
#     이름    키
# 0  채치수  197
# 1  정대만  184
# 2  송태섭  168
# 3  서태웅  187
# 4  강백호  188
# 5  변덕규  202
# 6  황태산  188
# 7  윤대협  190

# %% [markdown]
# ###DataFrame 객체 생성 (Index 지정)

# %%
df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ###DataFrame 객체 생성 (Column 지정)

# %%
df=pd.DataFrame(data,columns=['이름','키','학교'])
df
# Out:
#     이름    키   학교
# 0  채치수  197  북산고
# 1  정대만  184  북산고
# 2  송태섭  168  북산고
# 3  서태웅  187  북산고
# 4  강백호  188  북산고
# 5  변덕규  202  능남고
# 6  황태산  188  능남고
# 7  윤대협  190  능남고

# %% [markdown]
# ##Index

# %% [markdown]
# 데이터에 접근할 수 있는 주소

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df
# Out:
#      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 1번  채치수  북산고  197   90   85  100  95  85      Python
# 2번  정대만  북산고  184   40   35   50  55  25        Java
# 3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번  서태웅  북산고  187   40   60   70  75  80
# 5번  강백호  북산고  188   15   20   10  35  10
# 6번  변덕규  능남고  202   80  100   95  85  80           C
# 7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.index
# Out:
# Index(['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번'], dtype='object')

# %% [markdown]
# ###index 이름 설정

# %%
df.index.namae='지원번호'
df
# Out:
#    Unnamed: 0  정대만  북산고  184  40   35  50  55  25        Java
# 0           0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1           1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2           2  강백호  북산고  188  15   20  10  35  10         NaN
# 3           3  변덕규  능남고  202  80  100  95  85  80           C

# %% [markdown]
# ###index 초기화

# %%
df.reset_index()
# Out:
#   index   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0    1번  채치수  북산고  197   90   85  100  95  85      Python
# 1    2번  정대만  북산고  184   40   35   50  55  25        Java
# 2    3번  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3    4번  서태웅  북산고  187   40   60   70  75  80
# 4    5번  강백호  북산고  188   15   20   10  35  10
# 5    6번  변덕규  능남고  202   80  100   95  85  80           C
# 6    7번  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7    8번  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True) #원래 쓰던 '지원번호' 인덱스 삭제
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True,inplace=True) #실제 데이터에 반영

# %% [markdown]
# ###index 설정
# 지정한 column으로 index를 설정

# %%
df.set_index('이름')
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.set_index('이름',inplace=True)
df
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ###index 정렬

# %%
df.sort_index()
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 서태웅  북산고  187   40   60   70  75  80
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 윤대협  능남고  190  100   85   90  95  95          C#
# 정대만  북산고  184   40   35   50  55  25        Java
# 채치수  북산고  197   90   85  100  95  85      Python
# 황태산  능남고  188   55   65   45  40  35      PYTHON

# %%
df.sort_index(ascending=False)
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 윤대협  능남고  190  100   85   90  95  95          C#
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 변덕규  능남고  202   80  100   95  85  80           C
# 강백호  북산고  188   15   20   10  35  10

# %% [markdown]
# ##파일 저장 및 열기
# DataFrame 객체를 excel,scv,txt 등 형태의 파일로 저장 및 열

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
df=pd.DataFrame(data,index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name='지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ###저장하기
# csv파일로 저장

# %%
df.to_csv('score.csv')

# %%
df.to_csv('score.csv',encoding='utf-8-sig',index=False)

# %% [markdown]
# ###텍스트 파일로 저장

# %%
df.to_csv('score.txt',sep='\t')

# %% [markdown]
# ###엑셀 파일로 저장

# %%
df.to_excel('score.xlsx')

# %% [markdown]
# ###csv 파일로 열기

# %%
df=pd.read_csv('score.csv')
df
# Out:
#    정대만  북산고  184  40   35  50  55  25        Java
# 0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  강백호  북산고  188  15   20  10  35  10         NaN
# 3  변덕규  능남고  202  80  100  95  85  80           C

# %%
df=pd.read_csv('score_csv',skiprows=1) #지정된 개수의 row를 건너뜀
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-915591f1a02e> in <cell line: 1>()
# ----> 1 df=pd.read_csv('score_csv',skiprows=1) #지정된 개수의 row를 건너뜀
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df=pd.read_csv('score.csv',skiprows=[1,3,5]) # 1,3,5 row는 제외
df
# Out:
#    정대만  북산고  184  40   35  50  55  25 Java
# 0  서태웅  북산고  187  40   60  70  75  80  NaN
# 1  변덕규  능남고  202  80  100  95  85  80    C

# %%
df=pd.read_csv('score.csv',nrows=4)
df
# Out:
#    정대만  북산고  184  40   35  50  55  25        Java
# 0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  강백호  북산고  188  15   20  10  35  10         NaN
# 3  변덕규  능남고  202  80  100  95  85  80           C

# %%
df=pd.read_csv('score.csv',skiprows=2,nrows=4)
df
# Out:
#    서태웅  북산고  187  40   60  70  75  80 Unnamed: 8
# 0  강백호  북산고  188  15   20  10  35  10        NaN
# 1  변덕규  능남고  202  80  100  95  85  80          C

# %% [markdown]
# ###텍스트 파일 열기

# %%
df=pd.read_csv('score.txt',sep='\t')
df
# Out:
#    Unnamed: 0  정대만  북산고  184  40   35  50  55  25        Java
# 0           0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1           1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2           2  강백호  북산고  188  15   20  10  35  10         NaN
# 3           3  변덕규  능남고  202  80  100  95  85  80           C

# %%
df=pd.read_csv('score.txt',sep='\t')
df.set_index('이름',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-96e257b5970e> in <cell line: 2>()
#       1 df=pd.read_csv('score.txt',sep='\t')
# ----> 2 df.set_index('이름',inplace=True)
#       3 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['이름'] are in the columns"

# %% [markdown]
# ###엑셀 파일로 열

# %%
df=pd.read_excel('score.txt',index_col='지원번호')
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-9abc7f90dbba> in <cell line: 1>()
# ----> 1 df=pd.read_excel('score.txt',index_col='지원번호')
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %% [markdown]
# ##데이터 확인

# %%
df=pd.read_csv('score.csv')
df
# Out:
#    정대만  북산고  184  40   35  50  55  25        Java
# 0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  강백호  북산고  188  15   20  10  35  10         NaN
# 3  변덕규  능남고  202  80  100  95  85  80           C

# %% [markdown]
# ###DataFrame 확인
# 계산 가능한 데이터에 대해 column별로 데이터의 개수, 평균,표준편차,최소/최댓값 등의 정보를 보여줌

# %%
df.describe()  #데이터에 대한 정
# Out:
#               184         40          35         50         55         25
# count    4.000000   4.000000    4.000000   4.000000   4.000000   4.000000
# mean   186.250000  53.750000   63.750000  61.250000  68.750000  61.250000
# std     13.961256  31.983068   33.509949  36.142081  22.867371  34.247871
# min    168.000000  15.000000   20.000000  10.000000  35.000000  10.000000
# 25%    182.250000  33.750000   50.000000  55.000000  65.000000  58.750000
# 50%    187.500000  60.000000   67.500000  70.000000  77.500000  77.500000
# 75%    191.500000  80.000000   81.250000  76.250000  81.250000  80.000000
# max    202.000000  80.000000  100.000000  95.000000  85.000000  80.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   정대만     4 non-null      object
#  1   북산고     4 non-null      object
#  2   184     4 non-null      int64
#  3   40      4 non-null      int64
#  4   35      4 non-null      int64
#  5   50      4 non-null      int64
#  6   55      4 non-null      int64
#  7   25      4 non-null      int64
#  8   Java    2 non-null      object
# dtypes: int64(6), object(3)
# memory usage: 416.0+ bytes

# %%
df.head() #처음 5개의 row 가져
# Out:
#    정대만  북산고  184  40   35  50  55  25        Java
# 0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  강백호  북산고  188  15   20  10  35  10         NaN
# 3  변덕규  능남고  202  80  100  95  85  80           C

# %%
df.head(3) #처음 3개의 row를 가ㅕ종
# Out:
#    정대만  북산고  184  40  35  50  55  25        Java
# 0  송태섭  북산고  168  80  75  70  80  75  Javascript
# 1  서태웅  북산고  187  40  60  70  75  80         NaN
# 2  강백호  북산고  188  15  20  10  35  10         NaN

# %%
df.tail() #마지막 5개 row
# Out:
#    정대만  북산고  184  40   35  50  55  25        Java
# 0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  강백호  북산고  188  15   20  10  35  10         NaN
# 3  변덕규  능남고  202  80  100  95  85  80           C

# %%
df.tail(2) #마지막 2개 row 가져옴
# Out:
#    정대만  북산고  184  40   35  50  55  25 Java
# 2  강백호  북산고  188  15   20  10  35  10  NaN
# 3  변덕규  능남고  202  80  100  95  85  80    C

# %%
df.values
# Out:
# array([['송태섭', '북산고', 168, 80, 75, 70, 80, 75, 'Javascript'],
#        ['서태웅', '북산고', 187, 40, 60, 70, 75, 80, nan],
#        ['강백호', '북산고', 188, 15, 20, 10, 35, 10, nan],
#        ['변덕규', '능남고', 202, 80, 100, 95, 85, 80, 'C']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['정대만', '북산고', '184', '40', '35', '50', '55', '25', 'Java'], dtype='object')

# %%
df.shape #row, column
# Out:
# (4, 9)

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ###Series 확인

# %%
df['키'].describe()
# Out:
# count      8.000000
# mean     188.000000
# std        9.985704
# min      168.000000
# 25%      186.250000
# 50%      188.000000
# 75%      191.750000
# max      202.000000
# Name: 키, dtype: float64

# %%
df['키'].min()
# Out:
# 168

# %%
df['키'].max()
# Out:
# 202

# %%
df['키'].nlargest(3) #키 큰 사람 순서대로 3명 데이
# Out:
# 지원번호
# 6번    202
# 1번    197
# 8번    190
# 5번    188
# 7번    188
# Name: 키, dtype: int64

# %%
df['키'].mean()
# Out:
# 188.0

# %%
df['키'].sum()
# Out:
# 1504

# %%
df['SW특기'].count()
# Out:
# 8

# %%
df['학교'].unique()
# Out:
# array(['북산고', '능남고'], dtype=object)

# %%
df['학교'].nunique()
# Out:
# 2

# %% [markdown]
# ##데이터 선택

# %% [markdown]
# ###Column 선택 (label)

# %%
df['이름']
# Out:
# 지원번호
# 1번    채치수
# 2번    정대만
# 3번    송태섭
# 4번    서태웅
# 5번    강백호
# 6번    변덕규
# 7번    황태산
# 8번    윤대협
# Name: 이름, dtype: object

# %%
df['키']
# Out:
# 지원번호
# 1번    197
# 2번    184
# 3번    168
# 4번    187
# 5번    188
# 6번    202
# 7번    188
# 8번    190
# Name: 키, dtype: int64

# %%
df[['이름','키']]
# Out:
#        이름    키
# 지원번호
# 1번    채치수  197
# 2번    정대만  184
# 3번    송태섭  168
# 4번    서태웅  187
# 5번    강백호  188
# 6번    변덕규  202
# 7번    황태산  188
# 8번    윤대협  190

# %% [markdown]
# ###Clumn 선택(정수 index)

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.columns[0]
# Out:
# '이름'

# %%
df.columns[2]
# Out:
# '키'

# %%
df[df.columns[0]]
# Out:
# 지원번호
# 1번    채치수
# 2번    정대만
# 3번    송태섭
# 4번    서태웅
# 5번    강백호
# 6번    변덕규
# 7번    황태산
# 8번    윤대협
# Name: 이름, dtype: object

# %%
df[df.columns[0]] #df['이름']과 동일한 동작
# Out:
# 지원번호
# 1번    채치수
# 2번    정대만
# 3번    송태섭
# 4번    서태웅
# 5번    강백호
# 6번    변덕규
# 7번    황태산
# 8번    윤대협
# Name: 이름, dtype: object

# %%
df[df.columns[-1]] #맨 끝에 있는 값을 가져옴

# %% [markdown]
# ###슬라이싱

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['영어'][0:5] #0부터 4까지 영어 점수 데이터 가져옴
# Out:
# 지원번호
# 1번    85
# 2번    35
# 3번    75
# 4번    60
# 5번    20
# Name: 영어, dtype: int64

# %%
df[['이름','키']][:3]
# Out:
#        이름    키
# 지원번호
# 1번    채치수  197
# 2번    정대만  184
# 3번    송태섭  168

# %%
df[3:]
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 4번    서태웅  북산고  187   40   60  70  75  80
# 5번    강백호  북산고  188   15   20  10  35  10
# 6번    변덕규  능남고  202   80  100  95  85  80       C
# 7번    황태산  능남고  188   55   65  45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85  90  95  95      C#
